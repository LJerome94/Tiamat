# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def quadratic_map(z, c):
    return z*z+c

# %%
X = np.linspace(-2,1,1000)
Y = np.linspace(-1.5,1.5,1000)

X, Y = np.meshgrid(X,Y)

C = X + Y * 1.j

# %%
zn = C
for i in range(15):
    m = np.abs(zn)<4
    zn = np.where(m,quadratic_map(zn, C), zn)

R2 = np.abs(zn)
binary_set = R2<4

plt.figure()
plt.axis('off')
plt.imshow(binary_set, cmap='binary')
plt.savefig("test.png", dpi=1200, bbox_inches='tight')
